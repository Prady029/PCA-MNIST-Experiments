# %%
# update all packages
# !pip list --outdated --format=freeze | grep -v '^\-e' | cut -d = -f 1  | xargs -n1 pip install -U

# %% [markdown]
# # Import  libraries

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Set the parameters

# %%
#model parameter
batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# %% [markdown]
# # Loading the inbuilt data

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # Reshape the images

# %%
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

# %% [markdown]
# # Shape of the data

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # convert class vectors to binary class matrices

# %%
y_train = keras.utils.to_categorical(y_train, num_classes) #one-hot encoding for each label
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # My CNN Model

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

# %% [markdown]
# # Score in every epoch

# %% [markdown]
# # Fitting the model on train set and getting the cross entropy score on test dataset

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 170s 3ms/step - loss: 0.2565 - accuracy: 0.9205 - val_loss: 0.0599 - val_accuracy: 0.9813
# Epoch 2/12
# 60000/60000 [==============================] - 170s 3ms/step - loss: 0.0830 - accuracy: 0.9750 - val_loss: 0.0381 - val_accuracy: 0.9877
# Epoch 3/12
# 60000/60000 [==============================] - 170s 3ms/step - loss: 0.0630 - accuracy: 0.9812 - val_loss: 0.0338 - val_accuracy: 0.9891
# Epoch 4/12
# 60000/60000 [==============================] - 170s 3ms/step - loss: 0.0519 - accuracy: 0.9847 - val_loss: 0.0298 - val_accuracy: 0.9898
# Epoch 5/12
# 60000/60000 [==============================] - 170s 3ms/step - loss: 0.0438 - accuracy: 0.9866 - val_loss: 0.0303 - val_accuracy: 0.9904
# Epoch 6/12
# 60000/60000 [==============================] - 169s 3ms/step - loss: 0.0399 - accuracy: 0.9882 - val_loss: 0.0303 - val_accuracy: 0.9901
# Epoch 7/12
# ...

# %%
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.02852884491098521
# Test accuracy: 0.9919999837875366
